# %% [markdown]
# # Question 1 — TWFE & Event-Study

# %% [markdown]
# ## a) TWFE

# %% [markdown]
# ## b) Cleaning

# %% [markdown]
# ## c) Event-study

# %% [markdown]
# # Question 2 — CSDiD

# %% [markdown]
# # a)

# %%
# b)

# %%
# c)

# %%
# d)
